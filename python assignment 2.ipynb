# %%
age_list = [24, 25, 26, 27, 28]

# %%
name_list = ["Anu", "Meera", "Rahul", "Arjun", "Diya"]

print(name_list)
# Out:
# ['Anu', 'Meera', 'Rahul', 'Arjun', 'Diya']

# %%
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Anu', 'Meera', 'Rahul', 'Arjun', 'Diya', 'Yazhini']

# %%
age_list.insert(2,30)
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
name_list.remove("Yazhini")
print(name_list)
# Out:
# ['Anu', 'Meera', 'Rahul', 'Arjun', 'Diya']

# %%
age_list.pop()
print(age_list)
# Out:
# [24, 25, 30, 26, 27]

# %%
age_list.extend([29, 30, 26])

print(age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %%
age_list.sort()
print(age_list)
# Out:
# [24, 25, 26, 26, 27, 29, 30, 30]

# %%
age_list.reverse()
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
max(age_list)
# Out:
# 30

# %%
min(age_list)
# Out:
# 24

# %%
sum(age_list)
# Out:
# 217

# %%
print(name_list)
# Out:
# ['Anu', 'Meera', 'Rahul', 'Arjun']

# %%
name_list[0]
# Out:
# 'Anu'

# %%
name_list[-1]
# Out:
# 'Arjun'

# %%
name_list = ["Anu", "Meera", "Rahul", "Arjun", "Diya"]

# %%
name_list[2:5]
# Out:
# ['Rahul', 'Arjun', 'Diya']

# %%
name_list[::-1]
# Out:
# ['Diya', 'Arjun', 'Rahul', 'Meera', 'Anu']

# %%
student_marks={"Angana":99,"Nevin":87,"Vivek":67,"Akshay":88,"Ahana":56}

# %%
student_marks
# Out:
# {'Angana': 99, 'Nevin': 87, 'Vivek': 67, 'Akshay': 88, 'Ahana': 56}

# %%
print(student_marks["Nevin"])
# Out:
# 87

# %%
student_marks["Janani"]=80

# %%
student_marks
# Out:
# {'Angana': 99,
#  'Nevin': 87,
#  'Vivek': 67,
#  'Akshay': 88,
#  'Ahana': 56,
#  'Janani': 80}

# %%
student_marks["Vivek"]=82
print(student_marks)
# Out:
# {'Angana': 99, 'Nevin': 87, 'Vivek': 82, 'Akshay': 88, 'Ahana': 56, 'Janani': 80}

# %%
print(student_marks.keys())
# Out:
# dict_keys(['Angana', 'Nevin', 'Vivek', 'Akshay', 'Ahana', 'Janani'])

# %%
print(student_marks.items())
# Out:
# dict_items([('Angana', 99), ('Nevin', 87), ('Vivek', 82), ('Akshay', 88), ('Ahana', 56), ('Janani', 80)])

# %%
print(student_marks.values())
# Out:
# dict_values([99, 87, 82, 88, 56, 80])

# %%
my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}

# %%
my_set
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %% [markdown]
# set does not allow duplicates. Hence automatically removes them.

# %% [markdown]
# my_set[4] = 's'
# - for this set does not allow indexing.

# %%
set1 = {1, 3, 5, 7, 9}

set2 = {2, 3, 5, 8, 10}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
set1.intersection(set2)
# Out:
# {3, 5}

# %%
score=int(input("enter score: "))
if score>7:
    print("above average:exellent, keep up the good work")
elif score>=4:
    print("average:good effort, can do better")
else:
    print("below average, needs improvement, study more")
# Out:
# enter score:  5
# average:good effort, can do better
